# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %%
file_path_1 = 'D:\FREELANCE_PROJECTS\product-recommendation\data\All Electronics.csv'
file_path_2 = 'D:\FREELANCE_PROJECTS\product-recommendation\data\Air Conditioners (1).csv'

all_electronics_df = pd.read_csv(file_path_1)
air_conditioners_df = pd.read_csv(file_path_2)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\F'
# <>:2: SyntaxWarning: invalid escape sequence '\F'
# <>:1: SyntaxWarning: invalid escape sequence '\F'
# <>:2: SyntaxWarning: invalid escape sequence '\F'
# C:\Users\admin\AppData\Local\Temp\ipykernel_13372\808134193.py:1: SyntaxWarning: invalid escape sequence '\F'
#   file_path_1 = 'D:\FREELANCE_PROJECTS\product-recommendation\data\All Electronics.csv'
# C:\Users\admin\AppData\Local\Temp\ipykernel_13372\808134193.py:2: SyntaxWarning: invalid escape sequence '\F'
#   file_path_2 = 'D:\FREELANCE_PROJECTS\product-recommendation\data\Air Conditioners (1).csv'

# %%
all_electronics_df.head()
# Out:
#                                                 name        main_category  \
# 0  Redmi 10 Power (Power Black, 8GB RAM, 128GB St...  tv, audio & cameras
# 1  OnePlus Nord CE 2 Lite 5G (Blue Tide, 6GB RAM,...  tv, audio & cameras
# 2  OnePlus Bullets Z2 Bluetooth Wireless in Ear E...  tv, audio & cameras
# 3  Samsung Galaxy M33 5G (Mystique Green, 6GB, 12...  tv, audio & cameras
# 4  OnePlus Nord CE 2 Lite 5G (Black Dusk, 6GB RAM...  tv, audio & cameras
#
#       sub_category                                              image  \
# 0  All Electronics  https://m.media-amazon.com/images/I/81eM15lVcJ...
# 1  All Electronics  https://m.media-amazon.com/images/I/71AvQd3Vzq...
# 2  All Electronics  https://m.media-amazon.com/images/I/51UhwaQXCp...
# 3  All Electronics  https://m.media-amazon.com/images/I/81I3w4J6yj...
# 4  All Electronics  https://m.media-amazon.com/images/I/71V--WZVUI...
#
#                                                 link ratings no_of_ratings  \
# 0  https://www.amazon.in/Redmi-Power-Black-128GB-...     4.0           965
# 1  https://www.amazon.in/OnePlus-Nord-Lite-128GB-...     4.3       113,956
# 2  https://www.amazon.in/Oneplus-Bluetooth-Wirele...     4.2        90,304
# 3  https://www.amazon.in/Samsung-Mystique-Storage...     4.1        24,863
# 4  https://www.amazon.in/OnePlus-Nord-Black-128GB...     4.3       113,956
#
#   discount_price actual_price
# 0        ₹10,999      ₹18,999
# 1        ₹18,999      ₹19,999
# 2         ₹1,999       ₹2,299
# 3        ₹15,999      ₹24,999
# 4        ₹18,999      ₹19,999

# %%
air_conditioners_df.head()
# Out:
#                                                 name main_category  \
# 0  Lloyd 1.5 Ton 3 Star Inverter Split Ac (5 In 1...    appliances
# 1  LG 1.5 Ton 5 Star AI DUAL Inverter Split AC (C...    appliances
# 2  LG 1 Ton 4 Star Ai Dual Inverter Split Ac (Cop...    appliances
# 3  LG 1.5 Ton 3 Star AI DUAL Inverter Split AC (C...    appliances
# 4  Carrier 1.5 Ton 3 Star Inverter Split AC (Copp...    appliances
#
#        sub_category                                              image  \
# 0  Air Conditioners  https://m.media-amazon.com/images/I/31UISB90sY...
# 1  Air Conditioners  https://m.media-amazon.com/images/I/51JFb7FctD...
# 2  Air Conditioners  https://m.media-amazon.com/images/I/51JFb7FctD...
# 3  Air Conditioners  https://m.media-amazon.com/images/I/51JFb7FctD...
# 4  Air Conditioners  https://m.media-amazon.com/images/I/41lrtqXPiW...
#
#                                                 link ratings no_of_ratings  \
# 0  https://www.amazon.in/Lloyd-Inverter-Convertib...     4.2         2,255
# 1  https://www.amazon.in/LG-Convertible-Anti-Viru...     4.2         2,948
# 2  https://www.amazon.in/LG-Inverter-Convertible-...     4.2         1,206
# 3  https://www.amazon.in/LG-Convertible-Anti-Viru...     4.0            69
# 4  https://www.amazon.in/Carrier-Inverter-Split-C...     4.1           630
#
#   discount_price actual_price
# 0        ₹32,999      ₹58,990
# 1        ₹46,490      ₹75,990
# 2        ₹34,490      ₹61,990
# 3        ₹37,990      ₹68,990
# 4        ₹34,490      ₹67,790

# %%
file2_data.head()
# Out:
#                                                 name main_category  \
# 0  Lloyd 1.5 Ton 3 Star Inverter Split Ac (5 In 1...    appliances
# 1  LG 1.5 Ton 5 Star AI DUAL Inverter Split AC (C...    appliances
# 2  LG 1 Ton 4 Star Ai Dual Inverter Split Ac (Cop...    appliances
# 3  LG 1.5 Ton 3 Star AI DUAL Inverter Split AC (C...    appliances
# 4  Carrier 1.5 Ton 3 Star Inverter Split AC (Copp...    appliances
#
#        sub_category                                              image  \
# 0  Air Conditioners  https://m.media-amazon.com/images/I/31UISB90sY...
# 1  Air Conditioners  https://m.media-amazon.com/images/I/51JFb7FctD...
# 2  Air Conditioners  https://m.media-amazon.com/images/I/51JFb7FctD...
# 3  Air Conditioners  https://m.media-amazon.com/images/I/51JFb7FctD...
# 4  Air Conditioners  https://m.media-amazon.com/images/I/41lrtqXPiW...
#
#                                                 link  ratings no_of_ratings  \
# 0  https://www.amazon.in/Lloyd-Inverter-Convertib...      4.2         2,255
# 1  https://www.amazon.in/LG-Convertible-Anti-Viru...      4.2         2,948
# 2  https://www.amazon.in/LG-Inverter-Convertible-...      4.2         1,206
# 3  https://www.amazon.in/LG-Convertible-Anti-Viru...      4.0            69
# 4  https://www.amazon.in/Carrier-Inverter-Split-C...      4.1           630
#
#   discount_price actual_price
# 0        ₹32,999      ₹58,990
# 1        ₹46,490      ₹75,990
# 2        ₹34,490      ₹61,990
# 3        ₹37,990      ₹68,990
# 4        ₹34,490      ₹67,790

# %%
combined_df = pd.concat([all_electronics_df, air_conditioners_df], ignore_index=True)

# %%
combined_df.tail()
# Out:
#                                                     name main_category  \
# 10315  Personal Air Conditioners Portable AC Mini Air...    appliances
# 10316  Air Conditioner Fan Personal Desk Fan Space Ai...    appliances
# 10317  Portable Air Conditioners, Personal Air Condit...    appliances
# 10318  Portable Air Conditioner Fan, Personal Air Coo...    appliances
# 10319  Air Choice Desktop Protable AC Cooler Fan For ...    appliances
#
#            sub_category                                              image  \
# 10315  Air Conditioners  https://m.media-amazon.com/images/I/71RkCzQZyd...
# 10316  Air Conditioners  https://m.media-amazon.com/images/I/719ujjLfw7...
# 10317  Air Conditioners  https://m.media-amazon.com/images/I/71l59r1G-J...
# 10318  Air Conditioners  https://m.media-amazon.com/images/I/61GXC1nOlS...
# 10319  Air Conditioners  https://m.media-amazon.com/images/I/71yqMTaaWT...
#
#                                                     link ratings  \
# 10315  https://www.amazon.in/Personal-Conditioners-Po...
# 10316  https://www.amazon.in/Conditioner-Personal-Eva...
# 10317  https://www.amazon.in/Portable-Conditioners-Pe...
# 10318  https://www.amazon.in/Portable-Conditioner-Per...     2.8
# 10319  https://www.amazon.in/Air-Choice-Desktop-Prota...     2.5
#
#       no_of_ratings discount_price actual_price  \
# 10315                      ₹10,234      ₹13,999
# 10316                                    ₹9,881
# 10317                                    ₹6,361
# 10318           207                      ₹7,671
# 10319           296                      ₹8,592
#
#                                            text_features
# 10315  Personal Air Conditioners Portable AC Mini Air...
# 10316  Air Conditioner Fan Personal Desk Fan Space Ai...
# 10317  Portable Air Conditioners, Personal Air Condit...
# 10318  Portable Air Conditioner Fan, Personal Air Coo...
# 10319  Air Choice Desktop Protable AC Cooler Fan For ...

# %%
combined_df.fillna("", inplace=True)

# %%
combined_df['text_features'] = combined_df['name'] + " " + combined_df['sub_category']

# %%
tfidf_vectorizer = TfidfVectorizer(stop_words='english')

# %%
tfidf_matrix = tfidf_vectorizer.fit_transform(combined_df['text_features'])

# %%
cosine_sim_matrix = cosine_similarity(tfidf_matrix, tfidf_matrix)

# %%
def recommend_products(product_name, top_n=5):
    idx = combined_df[combined_df['name'].str.contains(product_name, case=False, na=False)].index
    if idx.empty:
        return "Product not found."
    
    sim_scores = list(enumerate(cosine_sim_matrix[idx[0]]))
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)
    
    recommended_indices = [i[0] for i in sim_scores[1:top_n + 1]]
    
    return combined_df.iloc[recommended_indices][['name', 'sub_category', 'discount_price']]

sample_recommendations = recommend_products("Redmi 10")
sample_recommendations
# Out:
#                                                    name     sub_category  \
# 5     Redmi 10 Power (Sporty Orange, 8GB RAM, 128GB ...  All Electronics
# 9390   Samsung Galaxy A53 Black, 8GB RAM, 128GB Storage  All Electronics
# 1646  OnePlus 11 5G (Titan Black, 8GB RAM, 128GB Sto...  All Electronics
# 9197  Redmi 10 (Caribbean Green, 6GB RAM, 128GB Stor...  All Electronics
# 1885   Redmi 10 (Midnight Black, 4GB RAM, 64GB Storage)  All Electronics
#
#      discount_price
# 5           ₹10,999
# 9390        ₹33,499
# 1646        ₹56,999
# 9197        ₹11,999
# 1885
